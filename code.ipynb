# %%
#Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
uni_df = pd.read_csv('../dataset/International_Education_Costs.csv') #Normal dataset I was going to use

# %%
uni_df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...

# %%
uni_df.describe()
# Out:
#        Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate
# count    907.000000     907.000000     907.000000
# mean     211.396913     700.077178     623.000695
# std      143.435740     320.374875    3801.746134
# min       40.000000     200.000000       0.150000
# 25%      100.000000     450.000000       0.920000
# 50%      160.000000     650.000000       1.350000
# ...

# %%
uni_df.describe(include={object})
# Out:
#        Country       City                University           Program   Level
# count      907        907                       907               907     907
# unique      71        556                       622                92       3
# top         UK  Singapore  University of Washington  Computer Science  Master
# freq        93         18                         6               312     451

# %%
uni_df.sort_values(by='Tuition_USD', ascending=False).head()
# Out:
#     Country      City             University                  Program   Level  \
# 877     USA  New York    Columbia University             Data Science  Master
# 412     USA  New York    Columbia University                Economics  Master
# 397     USA    Boston                    MIT         Computer Science  Master
# 452     USA   Chicago  University of Chicago             Data Science  Master
# 891     USA   Chicago  University of Chicago  Artificial Intelligence  Master
#
#      Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  Visa_Fee_USD  \
# 877             2.0        62000              100.0      2500           160
# 412             2.0        62000              100.0      2500           160
# 397             2.0        58000               82.1      2100           160
# 452             2.0        58000               84.1      1900           160
# 891             2.0        58000               84.1      1900           160
#
#      Insurance_USD  Exchange_Rate
# ...

# %%
uni_df.sort_values(by='Tuition_USD', ascending=True).head()
# Out:
#        Country           City                   University  \
# 761  Argentina        Mendoza  National University of Cuyo
# 705    Iceland  Hafnarfjordur   Iceland University of Arts
# 559     Sweden       Karlstad          Karlstad University
# 554     Sweden           Umeå              Umeå University
# 549     Sweden      Linköping         Linköping University
#
#                      Program     Level  Duration_Years  Tuition_USD  \
# 761           Data Analytics       PhD             4.0            0
# 705           Digital Design    Master             2.0            0
# 559      Information Systems  Bachelor             3.0            0
# 554  Artificial Intelligence    Master             2.0            0
# 549         Computer Science    Master             2.0            0
#
#      Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 761               36.8       230            90            280         275.00
# ...

# %%
uni_df['Tuition_rate'] = uni_df['Tuition_USD'] / uni_df['Duration_Years']

# %%
uni_df.sort_values(by='Tuition_rate', ascending=False)
# Out:
#     Country          City                 University               Program  \
# 398      UK        London    Imperial College London          Data Science
# 1        UK        London    Imperial College London          Data Science
# 101      UK        London  University College London      Computer Science
# 448      UK        London      King's College London      Computer Science
# 458      UK     Edinburgh     Heriot-Watt University      Computer Science
# ..      ...           ...                        ...                   ...
# 574  Greece  Thessaloniki       Aristotle University  Computer Engineering
# 579  Greece        Patras       University of Patras           Electronics
# 584  Greece     Heraklion        University of Crete      Computer Science
# 589  Greece         Volos     University of Thessaly       Digital Systems
# 499  Norway        Tromsø      UiT Arctic University     Marine Technology
#
# ...

# %%
country_rate = uni_df.groupby('Country')['Tuition_rate'].agg(['mean', 'median', 'max', 'min', 'count']).reset_index()

# %%
country_rate
# Out:
#        Country          mean        median      max     min  count
# 0      Algeria    415.000000    400.000000    550.0   300.0      5
# 1    Argentina      0.000000      0.000000      0.0     0.0      6
# 2    Australia  12977.228682  12166.666667  22900.0  6300.0     86
# 3      Austria    597.222222    500.000000    750.0   375.0      9
# 4      Bahrain   2675.000000   2250.000000   4000.0  1625.0      5
# ..         ...           ...           ...      ...     ...    ...
# 66         USA  16745.256410  12875.000000  31000.0  6625.0     78
# 67     Ukraine   1390.000000   1650.000000   1750.0   900.0      5
# 68     Uruguay   1350.000000      0.000000   3500.0     0.0      5
# 69  Uzbekistan   1425.000000   1600.000000   1900.0   875.0      5
# 70     Vietnam    800.000000    800.000000    800.0   800.0      1
#
# [71 rows x 6 columns]

# %%
country_level_group = uni_df.groupby(['Country', 'Level'])['Tuition_rate'].agg(['mean','median','max','min','count']).reset_index()

# %%
country_level_group[country_level_group['Country']=='USA']
# Out:
#     Country     Level          mean   median      max      min  count
# 175     USA  Bachelor  10391.071429  10462.5  14250.0   6625.0     28
# 176     USA    Master  25948.437500  26100.0  31000.0  19450.0     32
# 177     USA       PhD  10268.333333  10200.0  12750.0   7640.0     18

# %%
country_level_group[country_level_group['Country']=='UK']
# Out:
#     Country     Level          mean        median           max      min  \
# 172      UK  Bachelor   8891.805556   8883.333333  12833.333333   6100.0
# 173      UK    Master  28525.000000  31800.000000  42000.000000  16500.0
# 174      UK       PhD   8922.222222   8750.000000  11250.000000   7450.0
#
#      count
# 172     60
# 173     24
# 174      9

# %%
uni_country_level_group = uni_df.groupby(['Country', 'University','Level'])['Tuition_rate'].agg(['mean','median','max','min','count']).reset_index()

# %%
uni_country_level_group
# Out:
#         Country                            University     Level    mean  \
# 0       Algeria              Badji Mokhtar University    Master   500.0
# 1       Algeria             University of Constantine       PhD   325.0
# 2       Algeria                    University of Oran    Master   550.0
# 3       Algeria  University of Science and Technology  Bachelor   400.0
# 4       Algeria                 University of Tlemcen  Bachelor   300.0
# ..          ...                                   ...       ...     ...
# 787  Uzbekistan              Bukhara State University  Bachelor   875.0
# 788  Uzbekistan              INHA University Tashkent  Bachelor  1050.0
# 789  Uzbekistan                    Namangan Institute    Master  1700.0
# 790  Uzbekistan            Samarkand State University    Master  1900.0
# 791     Vietnam                                 HCMUT  Bachelor   800.0
#
#      median     max     min  count
# 0     500.0   500.0   500.0      1
# ...

# %%
uni_country_level_group[uni_country_level_group['University']=='University of Oxford']
# Out:
#     Country            University     Level          mean        median  \
# 701      UK  University of Oxford  Bachelor  12633.333333  12633.333333
# 702      UK  University of Oxford    Master  20000.000000  20000.000000
# 703      UK  University of Oxford       PhD   8725.000000   8725.000000
#
#               max           min  count
# 701  12633.333333  12633.333333      1
# 702  20000.000000  20000.000000      1
# 703  10000.000000   7450.000000      2

# %%
country_level_group[country_level_group['Country'] == 'UK']
# Out:
#     Country     Level          mean        median           max      min  \
# 172      UK  Bachelor   8891.805556   8883.333333  12833.333333   6100.0
# 173      UK    Master  28525.000000  31800.000000  42000.000000  16500.0
# 174      UK       PhD   8922.222222   8750.000000  11250.000000   7450.0
#
#      count
# 172     60
# 173     24
# 174      9

# %%
plt.figure(figsize=(6,4))
sns.histplot(uni_df['Tuition_rate'], bins=20, kde=True)
plt.title('Distribution of Tuition Rate Global (USD per Year)')
plt.xlabel('Tuition Rate')
plt.ylabel('Frequency')
plt.show()

# %%
#uk_comp_courses_for_me = uni_df[
#    (uni_df['Country'] == 'UK') &
#    (uni_df['Program'].str.contains('comp', case=False, na=False))  &
#    (uni_df['Level'] == 'Bachelor') &
#    (uni_df['Duration_Years'] == 3.0) 
#]
#uk_comp_courses_for_me.head()

# %%
#uk_comp_courses_for_me.to_csv('../dataset/WhatUniAmIGoingTo.csv')

# %%
#ranking_df = pd.read_csv('../dataset/Uni_Ranking_1625.csv') #Secondary dataset Im using to crossreference and make references with
#interest_df = pd.read_csv('../dataset/WhatUniAmIGoingTo.csv') #What we had earlier

# %%
#ranking_df.head()

# %%
#recent_information = ranking_df[(ranking_df['Year'] == 2025) & 
#                          (ranking_df['Country'] == 'United Kingdom')]

# %%
#recent_information

# %%
#I guess I will apply to Oxford, Imperial and UCL for Computer Science

# %%
#Maybe I can do more with this data

# %%
#uk_comp_courses_for_me.sort_values(by='Tuition_rate')

# %%
#uk_rankings_2025 = recent_information

# %%
#uk_rankings_2025.loc[:, 'Name'] = uk_rankings_2025['Name'].str.strip()
#uk_rankings_2025.loc[:, 'Country'] = uk_rankings_2025['Country'].str.strip()
#uk_comp_courses_for_me.loc[:, 'University'] = uk_comp_courses_for_me['University'].str.strip()
#uk_comp_courses_for_me.loc[:, 'Country'] = uk_comp_courses_for_me['Country'].str.strip()

# %%
#merged = pd.merge(
#    uk_rankings_2025, 
#    uk_comp_courses_for_me, 
#    left_on=['Name', 'Country'],
#    right_on=['University', 'Country'],
#    how='outer',
#    indicator=True
#)

# %%
#only_in_rankings = merged[merged['_merge'] == 'left_only']['Name'].tolist()
#only_in_courses  = merged[merged['_merge'] == 'right_only']['University'].tolist()

# %%
#merged_sorted = merged.sort_values('Tuition_rate')
#merged_sorted[['Name','Rank','Year','Program','Tuition_rate']]

# %%
#merged_sorted.sort_values(by='Rank', ascending=True)

# %%
#I notice there are issues in what I want, the tuition rate doesnt go with the data properly, the reason why is shown below:

# %%
uni_df[uni_df['University']=='University of Oxford'] #There are multiple values of tuition rate for the same uni
# Out:
#     Country    City            University               Program     Level  \
# 31       UK  Oxford  University of Oxford   Biomedical Sciences       PhD
# 235      UK  Oxford  University of Oxford      Computer Science  Bachelor
# 413      UK  Oxford  University of Oxford      Computer Science       PhD
# 864      UK  Oxford  University of Oxford  Software Engineering    Master
#
#      Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  Visa_Fee_USD  \
# 31              4.0        29800               74.5      1600           485
# 235             3.0        37900               77.8      1850           490
# 413             4.0        40000               71.5      1400           485
# 864             2.0        40000               71.5      1400           485
#
#      Insurance_USD  Exchange_Rate  Tuition_rate
# 31             800           0.79   7450.000000
# 235            800           0.79  12633.333333
# 413            800           0.79  10000.000000
# ...

# %%
uni_df['Avg_Uni_Tuition'] = uni_df.groupby('University')['Tuition_rate'].transform('mean') #So now Im going to basically doubleback and just get an average uni tuition rate

# %%
uni_df.sort_values(by='Avg_Uni_Tuition', ascending=False)
# Out:
#      Country          City               University               Program  \
# 468       UK    Manchester    University of Salford          Data Science
# 478       UK       Bristol              UWE Bristol      Computer Science
# 236       UK        London  Imperial College London      Computer Science
# 1         UK        London  Imperial College London          Data Science
# 398       UK        London  Imperial College London          Data Science
# ..       ...           ...                      ...                   ...
# 658   Brazil      Campinas                  UNICAMP  Computer Engineering
# 434  Germany       Cologne    University of Cologne           Mathematics
# 664   Brazil  Porto Alegre                    UFRGS          Data Science
# 670   Brazil        Recife                     UFPE  Computer Engineering
# 564   Sweden         Växjö      Linnaeus University  Software Engineering
#
#         Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# ...

# %%
uni_df[uni_df['University']=='University of Oxford']
# Out:
#     Country    City            University               Program     Level  \
# 31       UK  Oxford  University of Oxford   Biomedical Sciences       PhD
# 235      UK  Oxford  University of Oxford      Computer Science  Bachelor
# 413      UK  Oxford  University of Oxford      Computer Science       PhD
# 864      UK  Oxford  University of Oxford  Software Engineering    Master
#
#      Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  Visa_Fee_USD  \
# 31              4.0        29800               74.5      1600           485
# 235             3.0        37900               77.8      1850           490
# 413             4.0        40000               71.5      1400           485
# 864             2.0        40000               71.5      1400           485
#
#      Insurance_USD  Exchange_Rate  Tuition_rate  Avg_Uni_Tuition
# 31             800           0.79   7450.000000     12520.833333
# 235            800           0.79  12633.333333     12520.833333
# ...

# %%
#So now Im going to pinprick and restart halfway through to instead allow for avg_uni_tuition as our main metric
#The task has now changed to matching the rank of each uni with their average course tuition rate for international students coming to the UK

# %%
#uk_comp_courses_for_me.head()

# %%
#uk_comp_courses_for_me = uni_df[
#    (uni_df['Country'] == 'UK') &
#    (uni_df['Program'].str.contains('comp', case=False, na=False))  &
#    (uni_df['Level'] == 'Bachelor') &
#    (uni_df['Duration_Years'] == 3.0) 
#]
#uk_comp_courses_for_me.sort_values(by='Avg_Uni_Tuition', ascending=False).head()

# %%
#uk_rankings_2025 = recent_information

# %%
#merged = pd.merge(
#    uk_rankings_2025, 
#    uk_comp_courses_for_me, 
#    left_on=['Name', 'Country'],
#    right_on=['University', 'Country'],
#    how='outer',
#    indicator=True
#)

# %%
#merged_sorted = merged.sort_values('Tuition_rate')
#merged_sorted[['Name','Rank','Year','Program','Tuition_rate']]

# %%
#uni_df['Avg_Uni_Tuition'] = uni_df.groupby('University')['Tuition_rate'].transform('mean')

# %%
#uk_comp_courses_for_me = uni_df[
#    (uni_df['Country'] == 'UK') &
#    (uni_df['Program'].str.contains('comp', case=False, na=False)) &
#    (uni_df['Level'] == 'Bachelor') &
#    (uni_df['Duration_Years'] == 3.0)
#].copy()

# %%
#uk_comp_courses_for_me = uk_comp_courses_for_me.sort_values(by='Avg_Uni_Tuition', ascending=False)

# %%
#merged = pd.merge(
#    uk_rankings_2025, 
#    uk_comp_courses_for_me, 
#    left_on=['Name', 'Country'],
#    right_on=['University', 'Country'],
#    how='outer',
#    indicator=True
#)

# %%
#merged

# %%
#uk_comp_courses_for_me['University'] = uk_comp_courses_for_me['University'].str.strip().str.lower()
#uk_comp_courses_for_me['Country'] = uk_comp_courses_for_me['Country'].str.strip().str.lower()

#uk_rankings_2025['Name'] = uk_rankings_2025['Name'].str.strip().str.lower()
#uk_rankings_2025['Country'] = uk_rankings_2025['Country'].str.strip().str.lower()

# %%
uk_cs_courses = uni_df[
    (uni_df['Country'] == 'UK') &
    (uni_df['Program'].str.contains('comp', case=False, na=False))  &
    (uni_df['Level'] == 'Bachelor') &
    (uni_df['Duration_Years'] == 3.0) 
]
uk_cs_courses.sort_values(by='Avg_Uni_Tuition', ascending=False).head()
# Out:
#     Country     City                 University           Program     Level  \
# 236      UK   London    Imperial College London  Computer Science  Bachelor
# 237      UK   London  University College London  Computer Science  Bachelor
# 238      UK   London      King's College London  Computer Science  Bachelor
# 251      UK  Cardiff         Cardiff University  Computer Science  Bachelor
# 242      UK  Warwick      University of Warwick  Computer Science  Bachelor
#
#      Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  Visa_Fee_USD  \
# 236             3.0        37500               83.2      2200           490
# 237             3.0        36800               83.2      2100           490
# 238             3.0        35500               83.2      2000           490
# 251             3.0        28300               69.8      1050           490
# 242             3.0        31200               71.5      1300           490
#
# ...

# %%
uk_cs_courses.to_csv('../dataset/WhatUniAmIGoingTo.csv')

# %%
ranking_df = pd.read_csv('../dataset/Uni_Ranking_1625.csv')
interest_df = pd.read_csv('../dataset/WhatUniAmIGoingTo.csv')

# %%
uk_cs_courses.head()
# Out:
#     Country        City                  University               Program  \
# 105      UK  Birmingham    University of Birmingham  Computer Engineering
# 107      UK  Nottingham    University of Nottingham      Computer Science
# 109      UK     Belfast  Queen's University Belfast     Computing Systems
# 234      UK   Cambridge     University of Cambridge      Computer Science
# 235      UK      Oxford        University of Oxford      Computer Science
#
#         Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 105  Bachelor             3.0        29500               66.8       950
# 107  Bachelor             3.0        28900               64.8       850
# 109  Bachelor             3.0        27500               63.5       750
# 234  Bachelor             3.0        38500               78.5      1800
# 235  Bachelor             3.0        37900               77.8      1850
#
#      Visa_Fee_USD  Insurance_USD  Exchange_Rate  Tuition_rate  Avg_Uni_Tuition
# ...

# %%
uk_ranking = ranking_df[(ranking_df['Year'] == 2025) & 
                        (ranking_df['Country'] == 'United Kingdom')]

uk_ranking = uk_ranking.sort_values(by='Rank').reset_index(drop=True) #This was an edit I made later in the code
uk_ranking['UK_Rank'] = range(1, len(uk_ranking) + 1)

# %%
uk_ranking.head(10)
# Out:
#    Rank                                              Name         Country  \
# 0   1.0                              University of Oxford  United Kingdom
# 1   5.0                           University of Cambridge  United Kingdom
# 2   9.0                           Imperial College London  United Kingdom
# 3  22.0                                               UCL  United Kingdom
# 4  29.0                           University of Edinburgh  United Kingdom
# 5  37.0                             King’s College London  United Kingdom
# 6  51.0  London School of Economics and Political Science  United Kingdom
# 7  53.0                          University of Manchester  United Kingdom
# 8  78.0                             University of Bristol  United Kingdom
# 9  87.0                             University of Glasgow  United Kingdom
#
#    Student Population  Students to Staff Ratio International Students  \
# 0             22095.0                     10.8                    43%
# ...

# %%
uk_ranking.loc[:, 'Name'] = uk_ranking['Name'].str.strip()
uk_ranking.loc[:, 'Country'] = uk_ranking['Country'].str.strip()
uk_cs_courses.loc[:, 'University'] = uk_cs_courses['University'].str.strip()
uk_cs_courses.loc[:, 'Country'] = uk_cs_courses['Country'].str.strip()

# %%
merged = pd.merge(
    uk_cs_courses,
    uk_ranking,
    left_on=['University'],
    right_on=['Name'],
)

# %%
merged.head(10)
# Out:
#   Country_x        City                University               Program  \
# 0        UK  Birmingham  University of Birmingham  Computer Engineering
# 1        UK  Nottingham  University of Nottingham      Computer Science
# 2        UK   Cambridge   University of Cambridge      Computer Science
# 3        UK      Oxford      University of Oxford      Computer Science
# 4        UK      London   Imperial College London      Computer Science
# 5        UK  Manchester  University of Manchester      Computer Science
# 6        UK     Bristol     University of Bristol      Computer Science
# 7        UK     Warwick     University of Warwick      Computer Science
# 8        UK  Birmingham  University of Birmingham      Computer Science
# 9        UK       Leeds       University of Leeds      Computer Science
#
#       Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 0  Bachelor             3.0        29500               66.8       950
# ...

# %%
merged_sorted = merged.sort_values('Tuition_rate')
merged_sorted[['Rank','UK_Rank','Name','Year','Program','Tuition_rate','Avg_Uni_Tuition']].sort_values(by='Rank', ascending=True)
# Out:
#      Rank  UK_Rank                             Name  Year  \
# 3     1.0        1             University of Oxford  2025
# 2     5.0        2          University of Cambridge  2025
# 4     9.0        3          Imperial College London  2025
# 5    53.0        8         University of Manchester  2025
# 6    78.0        9            University of Bristol  2025
# 0    94.0       11         University of Birmingham  2025
# 8    94.0       11         University of Birmingham  2025
# 10   99.0       12          University of Sheffield  2025
# 7   106.0       13            University of Warwick  2025
# 12  115.0       14        University of Southampton  2025
# 9   123.0       15              University of Leeds  2025
# 11  138.0       16         University of Nottingham  2025
# 1   138.0       16         University of Nottingham  2025
# 26  141.0       17  Queen Mary University of London  2025
# 16  157.0       19             Newcastle University  2025
# ...

# %%
uni_entry = uk_ranking[uk_ranking['Name']== 'UCL'].copy()
uni_entry2 = uk_cs_courses[uk_cs_courses['University']=='University College London'].copy()

# %%
uni_entry
# Out:
#    Rank Name         Country  Student Population  Students to Staff Ratio  \
# 3  22.0  UCL  United Kingdom             41935.0                     11.1
#
#   International Students Female to Male Ratio  Overall Score  Teaching  \
# 3                    61%              60 : 40        87.7335      77.6
#
#    Research Environment  Research Quality  Industry Impact  \
# 3                  86.2              98.4             74.9
#
#    International Outlook  Year  UK_Rank
# 3                   97.7  2025        4

# %%
uni_dict = {'UCL':'University College London'} #Creating a dictionary to manually input a partcular uni
uni_entry['Name']=uni_entry['Name'].map(uni_dict)

# %%
uk_ranking = uk_ranking.copy() #Manipulating data is risky without doing .copy(), this should have been done earlier and I will remember this

# %%
def cast_uni_name(name):
    if name in uni_dict:
        return uni_dict[name]
    else:
        return name

# %%
uk_ranking['Name']=uk_ranking['Name'].apply(cast_uni_name)

# %%
uk_ranking
# Out:
#        Rank                       Name         Country  Student Population  \
# 0       1.0       University of Oxford  United Kingdom             22095.0
# 1       5.0    University of Cambridge  United Kingdom             20980.0
# 2       9.0    Imperial College London  United Kingdom             21000.0
# 3      22.0  University College London  United Kingdom             41935.0
# 4      29.0    University of Edinburgh  United Kingdom             37035.0
# ..      ...                        ...             ...                 ...
# 102  1327.0  University of South Wales  United Kingdom             16130.0
# 103  1341.0  University of Northampton  United Kingdom             10520.0
# 104  1443.0   University of Sunderland  United Kingdom             14080.0
# 105  1485.0    University of Worcester  United Kingdom              7300.0
# 106  1540.0      University of Chester  United Kingdom             11110.0
#
# ...

# %%
merged = pd.merge(
    uk_cs_courses,
    uk_ranking,
    left_on=['University'],
    right_on=['Name'],
)
merged
# Out:
#    Country_x            City                       University  \
# 0         UK      Birmingham         University of Birmingham
# 1         UK      Nottingham         University of Nottingham
# 2         UK       Cambridge          University of Cambridge
# 3         UK          Oxford             University of Oxford
# 4         UK          London          Imperial College London
# 5         UK          London        University College London
# 6         UK      Manchester         University of Manchester
# 7         UK         Bristol            University of Bristol
# 8         UK         Warwick            University of Warwick
# 9         UK      Birmingham         University of Birmingham
# 10        UK           Leeds              University of Leeds
# 11        UK       Sheffield          University of Sheffield
# 12        UK      Nottingham         University of Nottingham
# 13        UK     Southampton        University of Southampton
# ...

# %%
merged_sorted = merged.sort_values('Tuition_rate')
merged_sorted[['Rank','UK_Rank','Name','Year','Program','Tuition_rate','Avg_Uni_Tuition']].sort_values(by='Rank', ascending=True)
# Out:
#      Rank  UK_Rank                             Name  Year  \
# 3     1.0        1             University of Oxford  2025
# 2     5.0        2          University of Cambridge  2025
# 4     9.0        3          Imperial College London  2025
# 5    22.0        4        University College London  2025
# 6    53.0        8         University of Manchester  2025
# 7    78.0        9            University of Bristol  2025
# 9    94.0       11         University of Birmingham  2025
# 0    94.0       11         University of Birmingham  2025
# 11   99.0       12          University of Sheffield  2025
# 8   106.0       13            University of Warwick  2025
# 13  115.0       14        University of Southampton  2025
# 10  123.0       15              University of Leeds  2025
# 12  138.0       16         University of Nottingham  2025
# 1   138.0       16         University of Nottingham  2025
# 27  141.0       17  Queen Mary University of London  2025
# ...

# %%
merged_sorted.to_csv('../dataset/merged_sorted_dataset.csv', index=False)

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=merged_sorted, x='Rank', y='Avg_Uni_Tuition', hue='Name')
plt.title('Average University Tuition ($) vs. University Rank')
plt.xlabel('Rank')
plt.ylabel('Average University Tuition')
plt.gca().invert_xaxis()  # Lower rank means better university, so invert for visual logic
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.tight_layout()
plt.show()

# %%
uni_df[uni_df['University']=='Imperial College London']
# Out:
#     Country    City               University           Program     Level  \
# 1        UK  London  Imperial College London      Data Science    Master
# 236      UK  London  Imperial College London  Computer Science  Bachelor
# 398      UK  London  Imperial College London      Data Science    Master
#
#      Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  Visa_Fee_USD  \
# 1               1.0        41200               75.8      1800           485
# 236             3.0        37500               83.2      2200           490
# 398             1.0        42000               75.3      1800           485
#
#      Insurance_USD  Exchange_Rate  Tuition_rate  Avg_Uni_Tuition
# 1              800           0.79       41200.0          31900.0
# 236            800           0.79       12500.0          31900.0
# 398            800           0.79       42000.0          31900.0

# %%
tuition_sorted = merged.sort_values(by='Tuition_rate', ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(data=tuition_sorted, x='Tuition_rate', y='Name', hue='Name', palette='viridis')
plt.title('Tuition Rates of UK Universities (Computer Science)', fontsize=14)
plt.xlabel('Tuition Rate ($)')
plt.ylabel('University')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=tuition_sorted, x='Tuition_rate', y='Name', hue='Rank', palette='coolwarm'
)
plt.title('Tuition vs. University Rank', fontsize=14)
plt.xlabel('Tuition Rate ($)')
plt.ylabel('University')
plt.legend(title='World Rank', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=merged, x='Tuition_rate', color='skyblue')
plt.title('Distribution of Tuition Rates (Computer Science)', fontsize=14)
plt.xlabel('Tuition Rate ($)')
plt.grid(True, axis='x')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(merged_sorted['Avg_Uni_Tuition'], bins=20, kde=True)
plt.title('Distribution of Tuition Rate UK (USD per Year)')
plt.xlabel('Tuition Rate ($)')
plt.ylabel('Frequency')
plt.show()
